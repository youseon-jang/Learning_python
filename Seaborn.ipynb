# %% [markdown]
# ## Seaborn
# - visualizing statistical relationship

# %%
dowjones = sns.load_dataset("dowjones")
sns.relplot(data=dowjones, x="Date", y="Price", kind="line") ## relationplot 에서 kind = 'line'

# %% [markdown]
# - visualizing distributions of data

# %%
penguins = sns.load_dataset("penguins")
sns.displot(penguins, x="flipper_length_mm")  ### distribution plot

# %%
sns.displot(penguins, x="flipper_length_mm", hue="species", kind="kde", fill=True)

### distribution plot에서 kind = kernel density estimation plot

# %%
sns.displot(penguins, x="flipper_length_mm", kind="ecdf") 

## Empirical cumulative distributions

# %%
sns.displot(penguins, x="bill_length_mm", y="bill_depth_mm")

## Visualizing bivariate distributions

# %%
sns.relplot(data=penguins, x="bill_length_mm", y="bill_depth_mm")
sns.rugplot(data=penguins, x="bill_length_mm", y="bill_depth_mm")
# Out:
# <AxesSubplot:xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
sns.pairplot(penguins)

# %% [markdown]
# - visualizing categorical data

# %%
tips = sns.load_dataset("tips")
sns.catplot(data=tips, x="day", y="total_bill", jitter=False)

# %%
sns.catplot(data=tips, x="day", y="total_bill", kind="box")

# %%
sns.catplot(
    data=tips, x="total_bill", y="day", hue="sex", kind="violin",
)

# %%
titanic = sns.load_dataset("titanic")
sns.catplot(data=titanic, x="sex", y="survived", hue="class", kind="bar")

# %%
sns.catplot(data=titanic, x="sex", y="survived", hue="class", kind="point")
